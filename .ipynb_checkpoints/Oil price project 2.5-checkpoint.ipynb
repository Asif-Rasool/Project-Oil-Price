# %% [markdown]
# # Setting up the environment (note: please use a python kernal for this script)

# %% [markdown]
# ## Loading python packages

# %%
import pandas as pd # load and manipulate data for One-Hot ncoding
import numpy as np # calculate the mean and std. dev. 
import matplotlib.pyplot as plt # to plot figures
# !pip install xgboost --quiet
import xgboost as xgb # XGBoost engine..someone has to work, no?
from sklearn.model_selection import train_test_split # split data into training and testing sets
from sklearn.metrics import balanced_accuracy_score, roc_auc_score, make_scorer # for scoring during cross validations
from sklearn.model_selection import GridSearchCV # for cross validation
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Loading data

# %%
df = pd.DataFrame(pd.read_excel(r'C:\Users\asifr\OneDrive - State of New Mexico\Documents\Project Oil Price\Outputs\df_final.xlsx'))
pd.options.display.max_columns = 500
df = df.set_index('Date')
df.index = pd.to_datetime(df.index)
df = df.loc[df.index < '01-01-2024']
df
# Out:
#             nm_oil_price  wti_spot_price_sead  brent_spot_price_sead  \
# Date
# 2001-10-01     18.556667            -4.342383              -3.968467
# 2002-01-01     19.463333             0.427090               1.022115
# 2002-04-01     24.353333             4.314811               3.536845
# 2002-07-01     26.420000             1.127654               0.855471
# 2002-10-01     26.473333             1.891115               2.044512
# ...                  ...                  ...                    ...
# 2022-10-01     83.090000            -8.473781             -10.735306
# 2023-01-01     74.923333            -8.722612              -9.820590
# 2023-04-01     74.395000            -4.783938              -5.413929
# 2023-07-30     75.521729            -5.840083               2.325382
# 2023-10-28     73.139969           -13.529203             -17.535038
#
#             dubai_price_sead  index_china_gdp_sead  index_us_gdp_sead  \
# Date
# 2001-10-01         19.839120              0.006341          -1.463001
# 2002-01-01         21.054340              0.274799          -1.413006
# 2002-04-01         22.390446              0.304478          -2.565916
# 2002-07-01         25.571612              0.041236          -2.381250
# 2002-10-01         26.010084             -0.031823          -2.181999
# ...                      ...                   ...                ...
# 2022-10-01         86.095092             -0.111888          -0.254524
# 2023-01-01         83.411862             -0.039649          -0.316419
# 2023-04-01         81.985328              0.065365          -0.458359
# 2023-07-30         82.876366             -0.911323          -0.261623
# 2023-10-28         74.711807             -0.164480          -0.162122
#
#             index_cboe_volt_sead  us_unemploy_sead  index_ip_mining_sead  \
# Date
# 2001-10-01             25.182127          0.598185             -0.309495
# 2002-01-01             24.369796          0.248901             -2.856087
# 2002-04-01             22.733795          0.117970             -2.679328
# 2002-07-01             30.216726         -0.066227             -0.474966
# 2002-10-01             33.527721          0.067198             -3.076742
# ...                          ...               ...                   ...
# 2022-10-01             23.570406          0.082760              0.882243
# 2023-01-01             21.067296         -0.112388              0.732502
# 2023-04-01             16.543778          0.031577             -0.291814
# 2023-07-30             20.085571         -0.171856             -0.814330
# 2023-10-28             22.119646          0.032615              0.848376
#
#             index_cpi_china_sead    opec_sead  non_opec_sead  \
# Date
# 2001-10-01             -0.878374  2470.874362    4596.434309
# 2002-01-01             -0.483836   780.703619    -695.918912
# 2002-04-01             -0.611690   127.494978    -686.160537
# 2002-07-01              0.415096   991.461112    -508.238237
# 2002-10-01              0.164035   346.539986    -594.929577
# ...                          ...          ...            ...
# 2022-10-01             -0.903986    15.318944    -815.878169
# 2023-01-01             -0.464225  1380.280489   -1723.666000
# 2023-04-01             -1.142951   918.857486    -315.365854
# [89 rows x 29 columns]

# %% [markdown]
# # Visualizing the target variable : nm_oil_price

# %%
plt.plot(df['nm_oil_price'], label = 'Hisorical quarerly price')
plt.title('nm_oil_price')
plt.legend()

# %%
df_nm = df[['nm_oil_price']].copy(deep= True)

# %%
df_nm.head()
# Out:
#             nm_oil_price
# Date
# 2001-10-01     18.556667
# 2002-01-01     19.463333
# 2002-04-01     24.353333
# 2002-07-01     26.420000
# 2002-10-01     26.473333

# %%
df_nm.loc[(df_nm.index >= '2001-01-01') & (df_nm.index <= '2002-12-30')] \
    .plot(figsize=(15, 5), title='NM oil price during 911 attacks')
plt.show()

df_nm.loc[(df_nm.index >= '2005-04-01') & (df_nm.index <= '2006-10-01')] \
    .plot(figsize=(15, 5), title='NM oil during low spare capacity')
plt.show()

df_nm.loc[(df_nm.index >= '2007-01-01') & (df_nm.index <= '2008-12-30')] \
    .plot(figsize=(15, 5), title='NM oil price during global financial crisis')
plt.show()

df_nm.loc[(df_nm.index >= '2015-01-01') & (df_nm.index <= '2016-12-30')] \
    .plot(figsize=(15, 5), title='NM oil price during Opec supply cut')
plt.show()

df_nm.loc[(df_nm.index >= '2019-06-01') & (df_nm.index <= '2020-12-30')] \
    .plot(figsize=(15, 5), title='NM oil price during COVID19')

df_nm.loc[(df_nm.index >= '2022-01-01') & (df_nm.index <= '2022-12-30')] \
    .plot(figsize=(15, 5), title='NM oil price during Russie-Ukrain conflict')

plt.show()

# %%
def create_features(df_nm):
    """
    Create time series features based on time series index.
    """
    df_nm = df_nm.copy()
    df_nm['quarter'] = df_nm.index.quarter
    df_nm['year'] = df_nm.index.year
    return df_nm

df_nm = create_features(df_nm)

# %%
fig, ax = plt.subplots(figsize=(16, 8))
sns.boxplot(data=df_nm, x='year', y='nm_oil_price')
ax.set_title('NM oil Price by years')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(data=df_nm, x='quarter', y='nm_oil_price')
ax.set_title('NM oil Price by quarters')
plt.show()

# %% [markdown]
# # Creating train-test split

# %% [markdown]
# ## Plotting the train-test split

# %%
train = df.loc[df.index < '10-01-2018']
test = df.loc[(df.index >= '10-01-2018') & (df.index <= '2023-12-30')]

fig, ax = plt.subplots(figsize=(15, 5))
train["nm_oil_price"].plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test["nm_oil_price"].plot(ax=ax, label='Test Set')
ax.axvline('10-01-2018', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %% [markdown]
# ## Creating model features

# %%
train = create_features(train)
test = create_features(test)

FEATURES = ['wti_spot_price_sead', 'brent_spot_price_sead', 'dubai_price_sead',\
       'index_china_gdp_sead', 'index_us_gdp_sead', 'index_cboe_volt_sead',\
       'us_unemploy_sead', 'index_ip_mining_sead', 'index_cpi_china_sead',\
       'opec_sead', 'non_opec_sead', 'index_cpi_us_sead', 'index_energy_sead',\
       'index_metal_sead', 'index_precious_sead', 'del_supply_nonopec_sead',\
       'del_cap_per_sead', 'del_world_gdp_per_sead', 'del_supply_saudi_sead',\
       'opec_spare_capacity_sead', 'oecd_inventory_sead',\
       'del_world_consump_sead', 'sv_911', 'sv_covid19', 'sv_gfc', 'sv_lpc',\
       'sv_opec', 'sv_con22']

TARGET = 'nm_oil_price'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
# print(train.keys())
#X_train

# %% [markdown]
# # Running XGBoost regression

# %% [markdown]
# ## Running regreesion on train data

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=6000,
                       early_stopping_rounds=50,
                       objective='reg:squarederror',
                       max_depth=3,
                       learning_rate=0.001)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:65.47574	validation_1-rmse:67.03929
# [100]	validation_0-rmse:59.61069	validation_1-rmse:60.36523
# [200]	validation_0-rmse:54.28649	validation_1-rmse:54.32353
# [300]	validation_0-rmse:49.45089	validation_1-rmse:48.88861
# [400]	validation_0-rmse:45.06087	validation_1-rmse:43.95577
# [500]	validation_0-rmse:41.07632	validation_1-rmse:39.48705
# [600]	validation_0-rmse:37.46055	validation_1-rmse:35.46330
# [700]	validation_0-rmse:34.18094	validation_1-rmse:31.82669
# [800]	validation_0-rmse:31.20676	validation_1-rmse:28.56410
# [900]	validation_0-rmse:28.51125	validation_1-rmse:25.66314
# [1000]	validation_0-rmse:26.06969	validation_1-rmse:23.06708
# [1100]	validation_0-rmse:23.85902	validation_1-rmse:20.73210
# [1200]	validation_0-rmse:21.85950	validation_1-rmse:18.65878
# [1300]	validation_0-rmse:20.05227	validation_1-rmse:16.85052
# [1400]	validation_0-rmse:18.41557	validation_1-rmse:15.24249
# [1500]	validation_0-rmse:16.92744	validation_1-rmse:13.80312
# [1600]	validation_0-rmse:15.57315	validation_1-rmse:12.56216
# [1700]	validation_0-rmse:14.33743	validation_1-rmse:11.49419
# [1800]	validation_0-rmse:13.21154	validation_1-rmse:10.56150
# [1900]	validation_0-rmse:12.18626	validation_1-rmse:9.95188
# [2000]	validation_0-rmse:11.25038	validation_1-rmse:9.50432
# [2100]	validation_0-rmse:10.39502	validation_1-rmse:9.23915
# [2200]	validation_0-rmse:9.61101	validation_1-rmse:9.02558
# [2300]	validation_0-rmse:8.88930	validation_1-rmse:8.80537
# [2400]	validation_0-rmse:8.23823	validation_1-rmse:8.69073
# [2500]	validation_0-rmse:7.64616	validation_1-rmse:8.65971
# [2539]	validation_0-rmse:7.42972	validation_1-rmse:8.66730
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=6000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## Plotting variable importance

# %%
fi = pd.DataFrame(data=reg.feature_importances_, 
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', figsize=(16, 10), title='Feature Importance')
plt.show()

# %% [markdown]
# ## Fitting the model with test data

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df[['nm_oil_price']].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['True Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()
df.to_csv('file_name_1.csv')

# %% [markdown]
# ## Calculating mean squared error (MSE)

# %%
score = np.sqrt(mean_squared_error(test['nm_oil_price'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 8.66

# %% [markdown]
# ## Calcultating absolute sum of error (ASE)

# %%
ase = test['error'] = sum(np.abs(test[TARGET] - test['prediction']))
print(ase)
# Out:
# 142.88577863057452

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits=5, test_size=4*1, gap=0)
df = df.sort_index()

# %%
fig, axs = plt.subplots(5, 1, figsize=(15, 15), sharex=True)

fold = 0
for train_idx, val_idx in tss.split(df):
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]
    train['nm_oil_price'].plot(ax=axs[fold],
                          label='Training Set',
                          title=f'Data Train/Test Split Fold {fold}')
    test['nm_oil_price'].plot(ax=axs[fold],
                         label='Test Set')
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold += 1
plt.show()

# %% [markdown]
# # Model tuning

# %% [markdown]
# ## K-fold cross-validation

# %% [markdown]
# ### Creating folds, model features and running XGBoost regression

# %%
tss = TimeSeriesSplit(n_splits=5, test_size=4*1, gap=0)
df = df.sort_index()


fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(df):
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]

    train = create_features(train)
    test = create_features(test)

    FEATURES = ['wti_spot_price_sead', 'brent_spot_price_sead', 'dubai_price_sead',\
       'index_china_gdp_sead', 'index_us_gdp_sead', 'index_cboe_volt_sead',\
       'us_unemploy_sead', 'index_ip_mining_sead', 'index_cpi_china_sead',\
       'opec_sead', 'non_opec_sead', 'index_cpi_us_sead', 'index_energy_sead',\
       'index_metal_sead', 'index_precious_sead', 'del_supply_nonopec_sead',\
       'del_cap_per_sead', 'del_world_gdp_per_sead', 'del_supply_saudi_sead',\
       'opec_spare_capacity_sead', 'oecd_inventory_sead',\
       'del_world_consump_sead', 'sv_911', 'sv_covid19', 'sv_gfc', 'sv_lpc',\
       'sv_opec', 'sv_con22']
    
    TARGET = 'nm_oil_price'

    X_train = train[FEATURES]
    y_train = train[TARGET]

    X_test = test[FEATURES]
    y_test = test[TARGET]

    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                           n_estimators=800,
                           early_stopping_rounds=50,
                           objective='reg:squarederror',
                           max_depth=3,
                           learning_rate=0.01)
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)

    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)
# Out:
# [0]	validation_0-rmse:64.70886	validation_1-rmse:51.90357
# [100]	validation_0-rmse:25.70073	validation_1-rmse:17.68392
# [200]	validation_0-rmse:11.07126	validation_1-rmse:6.48637
# [300]	validation_0-rmse:5.28749	validation_1-rmse:3.95233
# [363]	validation_0-rmse:3.55869	validation_1-rmse:4.03674
# [0]	validation_0-rmse:64.07537	validation_1-rmse:36.65630
# [100]	validation_0-rmse:25.41500	validation_1-rmse:14.01557
# [200]	validation_0-rmse:10.94254	validation_1-rmse:5.74379
# [299]	validation_0-rmse:5.28996	validation_1-rmse:5.91929
# [0]	validation_0-rmse:62.94531	validation_1-rmse:65.67819
# [100]	validation_0-rmse:24.94314	validation_1-rmse:20.18514
# [200]	validation_0-rmse:10.72693	validation_1-rmse:10.58937
# [294]	validation_0-rmse:5.20817	validation_1-rmse:10.78790
# [0]	validation_0-rmse:63.08627	validation_1-rmse:94.27601
# [100]	validation_0-rmse:25.02106	validation_1-rmse:39.32221
# [200]	validation_0-rmse:10.69785	validation_1-rmse:17.73004
# [300]	validation_0-rmse:5.01902	validation_1-rmse:9.46625
# [400]	validation_0-rmse:2.67682	validation_1-rmse:8.26293
# [500]	validation_0-rmse:1.76769	validation_1-rmse:7.91175
# [600]	validation_0-rmse:1.30898	validation_1-rmse:7.63610
# [700]	validation_0-rmse:1.02236	validation_1-rmse:7.28129
# [799]	validation_0-rmse:0.82018	validation_1-rmse:7.08838
# [0]	validation_0-rmse:64.88588	validation_1-rmse:73.12335
# [100]	validation_0-rmse:25.62938	validation_1-rmse:17.83549
# [200]	validation_0-rmse:10.84786	validation_1-rmse:2.96961
# [256]	validation_0-rmse:6.93602	validation_1-rmse:4.82848

# %% [markdown]
# ### Calculating the fold scores

# %%
print(f'Score across folds {np.mean(scores):0.4f}')
print(f'Fold scores:{scores}')
# Out:
# Score across folds 5.4416
# Fold scores:[3.925933626877685, 3.017169868684828, 10.264967545885945, 7.084677466066542, 2.9153390527122354]

# %% [markdown]
# ### Plotting variable importance factors

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', figsize=(16, 10), title='Feature Importance')
plt.show()

# %% [markdown]
# ### Fitting the model with test data

# %%
test['prediction'] = reg.predict(X_test)
test
# Out:
#             nm_oil_price  wti_spot_price_sead  brent_spot_price_sead  \
# Date
# 2023-01-01     74.923333            -8.722612              -9.820590
# 2023-04-01     74.395000            -4.783938              -5.413929
# 2023-07-30     75.521729            -5.840083               2.325382
# 2023-10-28     73.139969           -13.529203             -17.535038
#
#             dubai_price_sead  index_china_gdp_sead  index_us_gdp_sead  \
# Date
# 2023-01-01         83.411862             -0.039649          -0.316419
# 2023-04-01         81.985328              0.065365          -0.458359
# 2023-07-30         82.876366             -0.911323          -0.261623
# 2023-10-28         74.711807             -0.164480          -0.162122
#
#             index_cboe_volt_sead  us_unemploy_sead  index_ip_mining_sead  \
# Date
# 2023-01-01             21.067296         -0.112388              0.732502
# 2023-04-01             16.543778          0.031577             -0.291814
# 2023-07-30             20.085571         -0.171856             -0.814330
# 2023-10-28             22.119646          0.032615              0.848376
#
#             index_cpi_china_sead    opec_sead  non_opec_sead  \
# Date
# 2023-01-01             -0.464225  1380.280489   -1723.666000
# 2023-04-01             -1.142951   918.857486    -315.365854
# 2023-07-30             -0.307783  1244.682861   -1779.296387
# 2023-10-28              0.054584   192.855942    -862.683350
#
#             index_cpi_us_sead  index_energy_sead  index_metal_sead  \
# Date
# 2023-01-01           0.384574           4.319581         10.418087
# 2023-04-01           0.116620           1.124914          3.925616
# 2023-07-30           0.131866           7.751447         13.733174
# 2023-10-28          -0.057139          12.629313         -6.686675
#
#             index_precious_sead  del_supply_nonopec_sead  del_cap_per_sead  \
# Date
# 2023-01-01            10.418087                 1.223792          2.035293
# 2023-04-01             3.925616                -0.094616          2.182216
# 2023-07-30            13.733174                -1.110270         -0.963215
# 2023-10-28            -6.686675                -0.014775          1.935422
#
#             del_world_gdp_per_sead  del_supply_saudi_sead  \
# Date
# 2023-01-01                2.035293               0.751176
# 2023-04-01                2.182216               0.393671
# 2023-07-30               -0.963215               0.706454
# 2023-10-28                1.935422               1.114867
#
#             opec_spare_capacity_sead  oecd_inventory_sead  \
# Date
# 2023-01-01                  1.026366           -62.081794
# 2023-04-01                  1.246305            54.538415
# 2023-07-30                  0.773252             2.757692
# 2023-10-28                  1.620810           -35.975090
#
#             del_world_consump_sead  sv_911  sv_con22  sv_covid19  sv_gfc  \
# Date
# 2023-01-01               -0.306870       0         0           0       0
# 2023-04-01               -0.172984       0         0           0       0
# 2023-07-30                3.257096       0         0           0       0
# 2023-10-28                5.173017       0         0           0       0
#
#             sv_lpc  sv_opec  prediction  quarter  year
# Date
# 2023-01-01       0        0   75.624176        1  2023
# 2023-04-01       0        0   70.648079        2  2023
# 2023-07-30       0        0   75.190437        3  2023
# 2023-10-28       0        0   77.539566        4  2023

# %%
# df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
df
# Out:
#             nm_oil_price  wti_spot_price_sead  brent_spot_price_sead  \
# Date
# 2001-10-01     18.556667            -4.342383              -3.968467
# 2002-01-01     19.463333             0.427090               1.022115
# 2002-04-01     24.353333             4.314811               3.536845
# 2002-07-01     26.420000             1.127654               0.855471
# 2002-10-01     26.473333             1.891115               2.044512
# ...                  ...                  ...                    ...
# 2022-10-01     83.090000            -8.473781             -10.735306
# 2023-01-01     74.923333            -8.722612              -9.820590
# 2023-04-01     74.395000            -4.783938              -5.413929
# 2023-07-30     75.521729            -5.840083               2.325382
# 2002-01-01                0.622355              -0.950975
# 2002-04-01               -0.357544              -1.017924
# 2002-07-01                1.004866              -0.274629
# 2002-10-01                1.064472              -0.146842
# ...                            ...                    ...
# 2022-10-01                1.104696              -0.193309
# 2023-01-01                2.035293               0.751176
# 2023-04-01                2.182216               0.393671
# 2023-07-30               -0.963215               0.706454
# 2023-10-28                1.935422               1.114867
#
#             opec_spare_capacity_sead  oecd_inventory_sead  \
# Date
# 2001-10-01                  2.910387            56.341081
# 2002-01-01                  2.310139            50.448373
# 2002-04-01                  2.234079           -14.152539
# 2002-07-01                  2.202959           -50.993165
# 2002-10-01                  2.272828           -47.218326
# ...                              ...                  ...
# 2022-10-01                  2.350821           -34.955475
# 2023-01-01                  1.026366           -62.081794
# 2023-04-01                  1.246305            54.538415
# 2023-07-30                  0.773252             2.757692
# 2023-10-28                  1.620810           -35.975090
#
#             del_world_consump_sead  sv_911  sv_con22  sv_covid19  sv_gfc  \
# Date
# 2001-10-01               -8.458096       1         0           0       0
# 2002-01-01               -1.040302       1         0           0       0
# 2002-04-01               -3.650842       1         0           0       0
# 2002-07-01                6.760543       1         0           0       0
# 2002-10-01                6.815767       1         0           0       0
# ...                            ...     ...       ...         ...     ...
# 2022-10-01                7.138162       0         1           0       0
# 2023-01-01               -0.306870       0         0           0       0
# 2023-04-01               -0.172984       0         0           0       0
# 2023-07-30                3.257096       0         0           0       0
# 2023-10-28                5.173017       0         0           0       0
#
#             sv_lpc  sv_opec  prediction
# Date
# 2001-10-01       0        0         NaN
# 2002-01-01       0        0         NaN
# 2002-04-01       0        0         NaN
# 2002-07-01       0        0         NaN
# 2002-10-01       0        0         NaN
# ...            ...      ...         ...
# 2022-10-01       0        0   81.127419
# 2023-01-01       0        0   81.193031
# 2023-04-01       0        0   79.881691
# 2023-07-30       0        0   88.344223
# 2023-10-28       0        0   79.976791
#
# [89 rows x 30 columns]

# %%
ax = df[['nm_oil_price']].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()
df.to_csv('file_name.csv')

# %% [markdown]
# ### Calculating mean squared error (MSE)

# %%
score = np.sqrt(mean_squared_error(test['nm_oil_price'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 2.92

# %% [markdown]
# ### Calcultating absolute sum of error (ASE)

# %%
ase = test['error'] = sum(np.abs(test[TARGET] - test['prediction']))
print(ase)
# Out:
# 9.17865214029952

# %% [markdown]
# # Running XGBoost using the entire datatset

# %%
df = pd.DataFrame(pd.read_excel(r'C:\Users\asifr\OneDrive - State of New Mexico\Documents\Project Oil Price\Outputs\df_final.xlsx'))
pd.options.display.max_columns = 500
df = df.set_index('Date')
df.index = pd.to_datetime(df.index)

train = df.loc[df.index < '04-01-2023']
test = df.loc[df.index >= '04-01-2023']

# fig, ax = plt.subplots(figsize=(15, 5))
# train["nm_oil_price"].plot(ax=ax, label='Training Set', title='Data Train/Test Split')
# test["nm_oil_price"].plot(ax=ax, label='Test Set')
# ax.axvline('04-01-2023', color='black', ls='--')
# ax.legend(['Training Set', 'Test Set'])
# plt.show()

# %%
train = create_features(train)
test = create_features(test)

FEATURES = ['wti_spot_price_sead', 'brent_spot_price_sead', 'dubai_price_sead',\
       'index_china_gdp_sead', 'index_us_gdp_sead', 'index_cboe_volt_sead',\
       'us_unemploy_sead', 'index_ip_mining_sead', 'index_cpi_china_sead',\
       'opec_sead', 'non_opec_sead', 'index_cpi_us_sead', 'index_energy_sead',\
       'index_metal_sead', 'index_precious_sead', 'del_supply_nonopec_sead',\
       'del_cap_per_sead', 'del_world_gdp_per_sead', 'del_supply_saudi_sead',\
       'opec_spare_capacity_sead', 'oecd_inventory_sead',\
       'del_world_consump_sead', 'sv_911', 'sv_covid19', 'sv_gfc', 'sv_lpc',\
       'sv_opec', 'sv_con22']

TARGET = 'nm_oil_price'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %% [markdown]
# ## Running regreesion on train data (entire dataset till year 2023)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=6000,
                       early_stopping_rounds=50,
                       objective='reg:squarederror',
                       max_depth=3,
                       learning_rate=0.001)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:65.55471	validation_1-rmse:71.90320
# [100]	validation_0-rmse:59.63405	validation_1-rmse:63.62001
# [200]	validation_0-rmse:54.26452	validation_1-rmse:56.10557
# [300]	validation_0-rmse:49.39751	validation_1-rmse:49.29060
# [400]	validation_0-rmse:44.98816	validation_1-rmse:43.11259
# [500]	validation_0-rmse:40.99272	validation_1-rmse:37.51532
# [600]	validation_0-rmse:37.37383	validation_1-rmse:32.44858
# [700]	validation_0-rmse:34.09674	validation_1-rmse:28.85675
# [800]	validation_0-rmse:31.12644	validation_1-rmse:25.25389
# [900]	validation_0-rmse:28.43309	validation_1-rmse:22.23433
# [1000]	validation_0-rmse:25.99174	validation_1-rmse:19.55230
# [1100]	validation_0-rmse:23.77991	validation_1-rmse:17.15874
# [1200]	validation_0-rmse:21.77363	validation_1-rmse:14.87368
# [1300]	validation_0-rmse:19.95202	validation_1-rmse:12.83931
# [1400]	validation_0-rmse:18.29708	validation_1-rmse:11.04360
# [1500]	validation_0-rmse:16.79402	validation_1-rmse:9.82258
# [1600]	validation_0-rmse:15.41701	validation_1-rmse:8.80770
# [1700]	validation_0-rmse:14.15353	validation_1-rmse:8.07691
# [1800]	validation_0-rmse:13.00290	validation_1-rmse:7.53953
# [1900]	validation_0-rmse:11.95523	validation_1-rmse:7.18847
# [2000]	validation_0-rmse:11.00110	validation_1-rmse:6.93947
# [2100]	validation_0-rmse:10.13232	validation_1-rmse:6.78915
# [2200]	validation_0-rmse:9.34161	validation_1-rmse:6.72831
# [2273]	validation_0-rmse:8.80921	validation_1-rmse:6.72922
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=6000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
fi = pd.DataFrame(data=reg.feature_importances_, 
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', figsize=(16, 10), title='Feature Importance')
plt.show()

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
# ax = df[['nm_oil_price']].plot(figsize=(15, 5))
# df['prediction'].plot(ax=ax, style='.')
# plt.legend(['True Data', 'Predictions'])
# ax.set_title('Raw Data and Prediction')
# plt.show()
#df.to_csv('file_name_1.csv')

# %%
actual = df.loc[df.index < '07-01-2023']
predicted = test.loc[(test.index >= '07-01-2023')]

fig, ax = plt.subplots(figsize=(15, 5))
actual["nm_oil_price"].plot(ax=ax, label='Historical price', title='Historical & Forecast')
test["nm_oil_price"].plot(ax=ax, label='Forecast')
ax.axvline('04-01-2023', color='black', ls='--')
ax.legend(['Historical price: nm_oil ($/barrel)', 'Forecasted price: nm_oil'])
plt.show()
